# %%
import functions
import ipywidgets as widgets

# %% [markdown]
# # New Subcategories that have been added

# %%
functions.render_section_addition_counts()
# Out:
#                      count
# subcategory
# Clothing              2986
# Beauty                 787
# Prof services          493
# Stores & shops         330
# TV channels            292
# eCommerce              275
# Cons electronics       250
# Games                  226
# Food                   208
# Sporting Goods         207
# Alcohol                196
# Software               195
# Technology             182
# Accessories            180
# Financial services     168
# Banks                  151
# Shoes                  144
# Bags                   130
# Online services        128
# Auto services          123
# Telecom                117
# Supermarkets           107
# ORGs/Companies         103
# Casual dining          101
# Insurance              100
# Energy                  97
# Household prod          95
# Airlines                90
# Healthcare              82
# Drinks                  81
# Watches                 79
# Auto makers             76
# Toys                    73
# ...

# %% [markdown]
# # Select a section to see whats been added

# %%
display(functions.show_section_select())
# Out:
# Dropdown(description='Subcategories:', options=('Accessories', 'Airlines', 'Alcohol', 'Auto makers', 'Auto ren…
#      Unnamed: 0   code                     name  i_median  i_from  i_average  \
# 997       BRdhw  BRdhw  Azul Brazilian Airlines  0.062730     0.0   0.062730
# 9715      BRc91  BRc91          Virgin Atlantic  0.174292     0.0   0.174292
# 5397      BReom  BReom            Star Alliance  0.187388     0.0   0.187388
# 9716      BRc9u  BRc9u         Virgin Australia  0.148427     0.0   0.148427
# 5569      BResb  BResb         TAP Air Portugal  0.085647     0.0   0.085647
# 985       BRdh8  BRdh8           Avior Airlines  0.000000     0.0   0.000000
# 5067      BRefu  BRefu                      SAS  0.099963     0.0   0.099963
# 6168      BRjk5  BRjk5                  WOW air  0.056282     0.0   0.056282
# 2806      BRf3o  BRf3o     Gulfstream Aerospace  0.082305     0.0   0.082305
# 5998      BRjfb  BRjfb          Virgin Galactic  0.057154     0.0   0.057154
# ...
